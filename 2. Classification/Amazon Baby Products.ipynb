# %% [markdown]
# ## Fire up pandas

# %%
import pandas as pd

# %% [markdown]
# ## Read some product review data

# %%
products = pd.read_csv('amazon_baby.csv')

# %%
len(products)
# Out:
# 183531

# %%
products.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %% [markdown]
# ## Build the word count vector for each review

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
word_count = vectorizer.fit_transform(products['review'].values.astype('U'))

# %%
print word_count.shape
# Out:
# (183531, 68032)

# %% [markdown]
# ## Build a sentiment classifier

# %% [markdown]
# ## Define what's a positive and a negative sentiment

# %% [markdown]
# ## positive sentiment = 4 or 5 * rating

# %%
products['sentiment'] = products['rating'] >= 4

# %%
products.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  sentiment
# 0  These flannel wipes are OK, but in my opinion ...       3      False
# 1  it came early and was not disappointed. i love...       5       True
# 2  Very soft and comfortable and warmer than it l...       5       True
# 3  This is a product well worth the purchase.  I ...       5       True
# 4  All of my kids have cried non-stop when I trie...       5       True

# %% [markdown]
# ## Let's train  the sentiment classifier

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(word_count, products['sentiment'])

# %% [markdown]
# ## Analyze built model

# %%
clf.coef_.shape
# Out:
# (1, 68032)

# %%
clf.coef_
# Out:
# array([[-10.33142725, -12.17725394, -15.47309081, ..., -15.47309081,
#         -15.47309081, -16.16623799]])

# %%
vectorizer.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'0001',
#  u'000ft',
#  u'000importer',
#  u'000sqft',
#  u'001',
#  u'001cm',
#  u'00am',
#  u'00amcreepy',
#  u'00cons',
#  u'00dollars',
#  u'00etwhile',
#  u'00not',
#  u'00pm',
#  u'01',
#  u'01262',
#  u'016sc01',
#  u'01992',
#  u'01p',
#  u'01wrgftjdd1bxmtbsg76',
#  u'02',
#  u'02000z',
#  u'02060',
#  u'02072',
#  u'02090',
#  u'020902nd',
#  u'0209a',
#  u'02100',
#  u'02100a',
#  u'0210a',
#  u'02180',
#  u'02220',
#  u'02640a',
#  u'02644',
#  u'02700',
#  u'02720',
#  u'03',
#  u'030',
#  u'0312258',
#  u'04',
#  u'0409',
#  u'0453',
#  u'046060us',
#  u'05',
#  u'05oz',
#  u'06',
#  u'0635',
#  u'07',
#  u'0752sjthe',
#  u'07pm',
#  u'07the',
#  u'08',
#  u'08280',
#  u'09',
#  u'093',
#  u'093010c',
#  u'09she',
#  u'09this',
#  u'0bviously',
#  u'0fast',
#  u'0ghz',
#  u'0ld',
#  u'0m',
#  u'0mm',
#  u'0ne',
#  u'0px',
#  u'0r',
#  u'0s',
#  u'0ver',
#  u'0z',
#  u'10',
#  u'100',
#  u'1000',
#  u'10000',
#  u'100000',
#  u'1000ccfor',
#  u'1000ma',
#  u'1000x',
#  u'10010',
#  u'10012telephone',
#  u'10084',
#  u'100ct',
#  u'100degree',
#  u'100f',
#  u'100feet',
#  u'100ft',
#  u'100lb',
#  u'100lbs',
#  u'100lbswill',
#  u'100mb',
#  u'100ml',
#  u'100next',
#  u'100oz',
#  u'100s',
#  u'100stars',
#  u'100th',
#  u'100x',
#  u'101',
#  u'101cm',
#  u'101f',
#  u'101looks',
#  u'102',
#  u'1027',
#  u'1029',
#  u'102degrees',
#  u'103',
#  u'1032',
#  u'103in',
#  u'104',
#  u'1040',
#  u'1041',
#  u'1042',
#  u'1044',
#  u'1045',
#  u'1046',
#  u'1047',
#  u'1048',
#  u'1049',
#  u'105',
#  u'1050',
#  u'1050f',
#  u'1051',
#  u'1052',
#  u'1053',
#  u'1054',
#  u'1055',
#  u'1056',
#  u'1057',
#  u'1058',
#  u'1059',
#  u'105lbs',
#  u'106',
#  u'1063',
#  u'1064',
#  u'1067',
#  u'1068',
#  u'1069',
#  u'107',
#  u'1071',
#  u'1072',
#  u'1073',
#  u'1074',
#  u'1075',
#  u'1076',
#  u'1077',
#  u'1078',
#  u'1079',
#  u'107lbs',
#  u'108',
#  u'1080',
#  u'1080p',
#  u'1081',
#  u'1082',
#  u'1083',
#  u'1084',
#  u'1085',
#  u'1086',
#  u'1087',
#  u'1088',
#  u'1089',
#  u'109',
#  u'1090',
#  u'1091',
#  u'1093',
#  u'1094',
#  u'1095',
#  u'1096',
#  u'1097',
#  u'1099',
#  u'10am',
#  u'10cm',
#  u'10dollar',
#  u'10feet',
#  u'10ft',
#  u'10g',
#  u'10h',
#  u'10hour',
#  u'10hours',
#  u'10hr',
#  u'10hrs',
#  u'10i',
#  u'10in',
#  u'10inches',
#  u'10is',
#  u'10ish',
#  u'10k',
#  u'10kg',
#  u'10lb',
#  u'10lbs',
#  u'10m',
#  u'10min',
#  u'10mins',
#  u'10minutes',
#  u'10mm',
#  u'10mo',
#  u'10month',
#  u'10months',
#  u'10more',
#  u'10mos',
#  u'10mph',
#  u'10mth',
#  u'10mths',
#  u'10ounce',
#  u'10oz',
#  u'10ozs',
#  u'10p',
#  u'10pc',
#  u'10pcs',
#  u'10pm',
#  u'10s',
#  u'10sec',
#  u'10secs',
#  u'10sq',
#  u'10th',
#  u'10v',
#  u'10week',
#  u'10wk',
#  u'10wks',
#  u'10x',
#  u'10x10',
#  u'10x12',
#  u'10x9',
#  u'10x9x2',
#  u'10xs',
#  u'10yo',
#  u'10yr',
#  u'10yrs',
#  u'11',
#  u'110',
#  u'1100',
#  u'1100mah',
#  u'1101',
#  u'1102',
#  u'1103',
#  u'1105',
#  u'1108',
#  u'11088',
#  u'110lb',
#  u'110lbs',
#  u'110mph',
#  u'110v',
#  u'111',
#  u'11138',
#  u'112',
#  u'112lb',
#  u'112lbs',
#  u'113',
#  u'1132',
#  u'114',
#  u'1142t',
#  u'1145am',
#  u'115',
#  u'115lb',
#  u'115lbs',
#  u'115v',
#  u'116',
#  u'117',
#  u'117lbs',
#  u'118',
#  u'118ml',
#  u'119',
#  u'1199b',
#  u'119lbs',
#  u'11a',
#  u'11after',
#  u'11am',
#  u'11b',
#  u'11edit',
#  u'11ft',
#  u'11g',
#  u'11h',
#  u'11having',
#  u'11hrs',
#  u'11i',
#  u'11inch',
#  u'11k',
#  u'11l',
#  u'11lb',
#  u'11lbs',
#  u'11m',
#  u'11mo',
#  u'11mon',
#  u'11month',
#  u'11months',
#  u'11mos',
#  u'11mth',
#  u'11mths',
#  u'11n',
#  u'11oz',
#  u'11pm',
#  u'11pounds',
#  u'11returned',
#  u'11s',
#  u'11th',
#  u'11the',
#  u'11we',
#  u'11week',
#  u'11x11x11',
#  u'11x14',
#  u'11x24',
#  u'11yr',
#  u'11yrs',
#  u'12',
#  u'120',
#  u'1200',
#  u'1200sq',
#  u'120100',
#  u'120ac',
#  u'120f',
#  u'120firm',
#  u'120ish',
#  u'120lb',
#  u'120lbs',
#  u'120mah',
#  u'120ml',
#  u'120us',
#  u'120v',
#  u'1219',
#  u'122',
#  u'1220',
#  u'1227',
#  u'12288',
#  u'12289',
#  u'12290',
#  u'122inch',
#  u'122lb',
#  u'123',
#  u'1230',
#  u'1231',
#  u'123s',
#  u'124',
#  u'1246131975',
#  u'125',
#  u'1250',
#  u'125cc',
#  u'125f',
#  u'125lb',
#  u'125mhz2444',
#  u'125mhz2462',
#  u'126',
#  u'127',
#  u'1270',
#  u'1273',
#  u'127lbs',
#  u'127v',
#  u'1280306464',
#  u'128076',
#  u'128077',
#  u'128079',
#  u'128125',
#  u'128512',
#  u'128514',
#  u'128515',
#  u'128522',
#  u'128525',
#  u'128532',
#  u'128540',
#  u'128548',
#  u'128571',
#  u'128575',
#  u'129',
#  u'129020lv',
#  u'1291773849',
#  u'1291774118',
#  u'12am',
#  u'12ball',
#  u'12bs',
#  u'12bucks',
#  u'12ft',
#  u'12grams',
#  u'12h',
#  u'12hour',
#  u'12hr',
#  u'12hrs',
#  u'12i',
#  u'12in',
#  u'12inch',
#  u'12inches',
#  u'12kg',
#  u'12lb',
#  u'12lbs',
#  u'12m',
#  u'12mm',
#  u'12mo',
#  u'12month',
#  u'12months',
#  u'12mos',
#  u'12moth',
#  u'12mth',
#  u'12mths',
#  u'12my',
#  u'12o',
#  u'12ok',
#  u'12oz',
#  u'12pack',
#  u'12pm',
#  u'12th',
#  u'12updated',
#  u'12v',
#  u'12vdc',
#  u'12volt',
#  u'12volts',
#  u'12weeks',
#  u'12wk',
#  u'12wks',
#  u'12x',
#  u'12x10',
#  u'12x12',
#  u'12x12in',
#  u'12x13',
#  u'12x48',
#  u'12yo',
#  u'12yrs',
#  u'13',
#  u'130',
#  u'1300',
#  u'1300oz',
#  u'1303583995',
#  u'130f',
#  u'130ish',
#  u'130lb',
#  u'130lbs',
#  u'131',
#  u'1317',
#  u'131cm',
#  u'132',
#  u'1326473230',
#  u'1327',
#  u'1329922739',
#  u'133',
#  u'1332983943',
#  u'1336590026',
#  u'1337219171',
#  u'1339620189',
#  u'1339678162',
#  u'134',
#  u'1341',
#  u'1343084111',
#  u'1348588962',
#  u'1348806657',
#  u'135',
#  u'1355248679',
#  u'1356056053',
#  u'1357838224',
#  u'1358790060',
#  u'135lbs',
#  u'136',
#  u'1360350',
#  u'1360729347',
#  u'1361203641',
#  u'1362030292',
#  u'1362660640',
#  u'1362660801',
#  u'1363012209',
#  u'1363819860',
#  u'1367022549',
#  u'1367022582',
#  u'1367510554',
#  u'137',
#  u'1370027586',
#  u'1370479569',
#  u'1371446810',
#  u'1371660713',
#  u'1371660739',
#  u'1372124283',
#  u'1372233037',
#  u'138',
#  u'1380243177',
#  u'138lbs',
#  u'139',
#  u'1390005911',
#  u'1390183256',
#  u'1393526392',
#  u'1394068905',
#  u'1394582174',
#  u'1395934717',
#  u'1396485221',
#  u'1398',
#  u'13after',
#  u'13baby',
#  u'13do',
#  u'13g',
#  u'13gallon',
#  u'13i',
#  u'13in',
#  u'13ish',
#  u'13kg',
#  u'13lb',
#  u'13lbs',
#  u'13m',
#  u'13mm',
#  u'13mo',
#  u'13mons',
#  u'13month',
#  u'13months',
#  u'13mth',
#  u'13mths',
#  u'13my',
#  u'13oz',
#  u'13pc',
#  u'13pcs',
#  u'13th',
#  u'13the',
#  u'13w',
#  u'13we',
#  u'13x16',
#  u'13x18',
#  u'13yr',
#  u'14',
#  u'140',
#  u'1400',
#  u'1400550753',
#  u'1403388276',
#  u'1403672820',
#  u'1403672910',
#  u'1403672986',
#  u'1404007570',
#  u'1404321797',
#  u'140f',
#  u'140lb',
#  u'140lbs',
#  u'141',
#  u'1410',
#  u'1412',
#  u'143',
#  u'144',
#  u'145',
#  u'1450',
#  u'145lbs',
#  u'146',
#  u'1460',
#  u'1470',
#  u'148',
#  u'148weight',
#  u'149',
#  u'149lbs',
#  u'14cfr',
#  u'14hr',
#  u'14hrs',
#  u'14i',
#  u'14in',
#  u'14lb',
#  u'14lbs',
#  u'14m',
#  u'14mo',
#  u'14month',
#  u'14months',
#  u'14mos',
#  u'14mths',
#  u'14oz',
#  u'14ozs',
#  u'14pounds',
#  u'14th',
#  u'14x',
#  u'14x14',
#  u'14x18',
#  u'14x20',
#  u'14x29',
#  u'14x9',
#  u'14year',
#  u'14yr',
#  u'14yrs',
#  u'15',
#  u'150',
#  u'1500',
#  u'15000',
#  u'1500ma',
#  u'1500sq',
#  u'150ft',
#  u'150ish',
#  u'150lbs',
#  u'150ml',
#  u'150mland',
#  u'150mlfor',
#  u'150shipped',
#  u'151',
#  u'152',
#  u'154',
#  u'155',
#  u'156',
#  u'157',
#  u'158',
#  u'158lbs',
#  u'159',
#  u'1590',
#  u'15a',
#  u'15am',
#  u'15cm',
#  u'15days',
#  u'15dec2013after',
#  u'15ft',
#  u'15in',
#  u'15ish',
#  u'15kg',
#  u'15lb',
#  u'15lb1oz',
#  u'15lbs',
#  u'15lbsi',
#  u'15m',
#  u'15min',
#  u'15mins',
#  u'15minutes',
#  u'15ml',
#  u'15mo',
#  u'15month',
#  u'15months',
#  u'15mos',
#  u'15mth',
#  u'15mths',
#  u'15oz',
#  u'15pc',
#  u'15pm',
#  u'15psi',
#  u'15th',
#  u'15x',
#  u'15x28',
#  u'15x33',
#  u'15yrs',
#  u'16',
#  u'160',
#  u'1600',
#  u'1600ft',
#  u'160cm',
#  u'160lbs',
#  u'160ml',
#  u'162',
#  u'162cm',
#  u'164',
#  u'165',
#  u'1650',
#  u'168',
#  u'169',
#  u'16d',
#  u'16hr',
#  u'16in',
#  u'16inches',
#  u'16kg',
#  u'16lb',
#  u'16lbs',
#  u'16m',
#  u'16mo',
#  u'16month',
#  u'16monthh',
#  u'16months',
#  u'16mos',
#  u'16mt',
#  u'16mth',
#  u'16mths',
#  u'16oz',
#  u'16pounds',
#  u'16th',
#  u'16thless',
#  u'16w',
#  u'16wks',
#  u'16x20',
#  u'16x26',
#  u'16x29',
#  u'16x32',
#  u'17',
#  u'170',
#  u'1700',
#  u'170ish',
#  u'170lb',
#  u'170lbs',
#  u'172',
#  u'175',
#  u'175lbs',
#  u'176',
#  u'177',
#  u'178',
#  u'1789',
#  u'179',
#  u'17ib',
#  u'17ibs',
#  u'17in',
#  u'17inches',
#  u'17lb',
#  u'17lbs',
#  u'17m',
#  u'17mo',
#  u'17month',
#  u'17months',
#  u'17mths',
#  u'17oz',
#  u'17th',
#  u'17w',
#  u'17weeks',
#  u'17wks',
#  u'17x18',
#  u'17x24',
#  u'17x35',
#  u'18',
#  u'180',
#  u'1800',
#  u'1800mah',
#  u'180degrees',
#  u'180lb',
#  u'180lbs',
#  u'180mah',
#  u'180ml',
#  u'182',
#  u'184',
#  u'185',
#  u'1850sqft',
#  u'185lb',
#  u'185lbs',
#  u'186',
#  u'1860',
#  u'18650',
#  u'189',
#  u'1891',
#  u'1894',
#  u'1899',
#  u'18b',
#  u'18hrs',
#  u'18in',
#  u'18inch',
#  u'18inches',
#  u'18inchs',
#  u'18ish',
#  u'18kg',
#  u'18lb',
#  u'18lbs',
#  u'18m',
#  u'18mb',
#  u'18mins',
#  u'18mo',
#  u'18mon',
#  u'18month',
#  u'18months',
#  u'18mos',
#  u'18mth',
#  u'18mths',
#  u'18pds',
#  u'18th',
#  u'18ths',
#  u'18wk',
#  u'18x18',
#  u'18x27',
#  u'18x30',
#  u'18x31',
#  u'18x36',
#  u'19',
#  u'190',
#  u'1900',
#  u'1905',
#  u'190degree',
#  u'190lbs',
#  u'190ml',
#  u'1912',
#  u'1916',
#  u'1918',
#  u'192',
#  u'1920',
#  u'1920s',
#  u'1926',
#  u'1930s',
#  u'1932',
#  u'1939',
#  u'1940',
#  u'1942',
#  u'1945',
#  u'1950',
#  u'1950s',
#  u'1953',
#  u'1954',
#  u'1956',
#  u'1960',
#  u'1960s',
#  u'1961',
#  u'1966',
#  u'1967',
#  u'1968',
#  u'1969',
#  u'1970',
#  u'1970s',
#  u'1971',
#  u'1972',
#  u'1973',
#  u'1975',
#  u'1977',
#  u'1979',
#  u'198',
#  u'1980',
#  u'1980ies',
#  u'1980s',
#  u'1981',
#  u'1983',
#  u'1983after',
#  u'1984',
#  u'1985',
#  u'1986',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'199',
#  u'1990',
#  u'1990s',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'19968',
#  u'1997',
#  u'19978',
#  u'19979',
#  u'1998',
#  u'19981',
#  u'1999',
#  u'19996',
#  u'19am',
#  u'19lb',
#  u'19lbs',
#  u'19m',
#  u'19mbps',
#  u'19mm',
#  u'19mo',
#  u'19month',
#  u'19months',
#  u'19mos',
#  u'19mths',
#  u'19pm',
#  u'19sq',
#  u'19sqft',
#  u'19th',
#  u'19x',
#  u'19x30',
#  u'1a',
#  u'1although',
#  u'1am',
#  u'1bs',
#  u'1cm',
#  u'1cmx2cm',
#  u'1cup',
#  u'1d',
#  u'1f',
#  u'1first',
#  u'1ft',
#  u'1h',
#  u'1he',
#  u'1hnbh6g05zmf34xezf2v',
#  u'1hour',
#  u'1hr',
#  u'1hrs',
#  u'1i',
#  u'1in',
#  u'1inch',
#  u'1it',
#  u'1k',
#  u'1kwh',
#  u'1l',
#  u'1lbs',
#  u'1m',
#  u'1m3dkhhaa9q4xp1g9sh7or',
#  u'1mb',
#  u'1min',
#  u'1ml',
#  u'1mm',
#  u'1mo',
#  u'1month',
#  u'1mos',
#  u'1n',
#  u'1or',
#  u'1or2',
#  u'1oz',
#  u'1p',
#  u'1pack',
#  u'1pk',
#  u'1pm',
#  u'1s',
#  u'1second',
#  u'1st',
#  u'1star',
#  u'1stgrand',
#  u'1t',
#  u'1the',
#  u'1thing',
#  u'1this',
#  u'1tr',
#  u'1ts',
#  u'1tsp',
#  u'1w',
#  u'1week',
#  u'1wk',
#  u'1x',
#  u'1x1',
#  u'1x1in',
#  u'1x1s',
#  u'1x2',
#  u'1x3',
#  u'1x4',
#  u'1x6',
#  u'1y',
#  u'1yea',
#  u'1year',
#  u'1yo',
#  u'1yos',
#  u'1yr',
#  u'1yro',
#  u'1yrs',
#  u'1z',
#  u'20',
#  u'200',
#  u'2000',
#  u'2000ft',
#  u'2000km',
#  u'2000ma',
#  u'2000sf',
#  u'2000sq',
#  u'2001',
#  u'20010',
#  u'20011',
#  u'20013',
#  u'2001485',
#  u'2002',
#  u'20026',
#  u'2003',
#  u'20037',
#  u'2004',
#  u'20040',
#  u'2005',
#  u'2005added',
#  u'2006',
#  u'20063',
#  u'2006bryce',
#  u'2006my',
#  u'2007',
#  u'2007regarding',
#  u'2007release',
#  u'2008',
#  u'20080',
#  u'2008reviewer',
#  u'2008still',
#  u'2009',
#  u'2009this',
#  u'200a',
#  u'200ft',
#  u'200lb',
#  u'200lbs',
#  u'200ml',
#  u'200mm',
#  u'200someting',
#  u'200sq',
#  u'200z',
#  u'2010',
#  u'20102',
#  u'2010i',
#  u'2010it',
#  u'2010one',
#  u'2010well',
#  u'2011',
#  u'20110',
#  u'20110807',
#  u'20114',
#  u'2011after',
#  u'2011its',
#  u'2011just',
#  u'2011our',
#  u'2011we',
#  u'2011went',
#  u'2012',
#  u'201207',
#  u'20126',
#  u'2012a',
#  u'2012after',
#  u'2012by',
#  u'2012i',
#  u'2012kudos',
#  u'2012looks',
#  u'2012my',
#  u'2012the',
#  u'2012this',
#  u'2012we',
#  u'2013',
#  u'20132',
#  u'2013after',
#  u'2013and',
#  u'2013as',
#  u'2013i',
#  u'2013my',
#  u'2013our',
#  u'2013since',
#  u'2013so',
#  u'2013still',
#  u'2013was',
#  u'2013we',
#  u'2013well',
#  u'2014',
#  u'20142',
#  u'2014after',
#  u'2014during',
#  u'2014i',
#  u'2014less',
#  u'2014now',
#  u'2014our',
#  u'2014so',
#  u'2014still',
#  ...]

# %% [markdown]
# ## Building a pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()), ])

# %% [markdown]
# ## Train the model using the pipeline

# %%
text_clf.fit(products.review.values.astype('U'), products.sentiment)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         st...False,
#          use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %% [markdown]
# ## predicting probabilities

# %%
products['prediction'] = text_clf.predict_proba(products.review.values.astype('U'))[:, [True, False]]

# %% [markdown]
# ## Examining the reviews for most sold product: 'Vulli Sophie the Giraffe Teether'

# %%
giraffe_reviews = products[products['name'] == 'Vulli Sophie the Giraffe Teether']

# %%
len(giraffe_reviews)
# Out:
# 785

# %%
giraffe_reviews.head()
# Out:
#                                    name  \
# 34313  Vulli Sophie the Giraffe Teether
# 34314  Vulli Sophie the Giraffe Teether
# 34315  Vulli Sophie the Giraffe Teether
# 34316  Vulli Sophie the Giraffe Teether
# 34317  Vulli Sophie the Giraffe Teether
#
#                                                   review  rating  sentiment  \
# 34313  He likes chewing on all the parts especially t...       5       True
# 34314  My son loves this toy and fits great in the di...       5       True
# 34315  There really should be a large warning on the ...       1      False
# 34316  All the moms in my moms' group got Sophie for ...       5       True
# 34317  I was a little skeptical on whether Sophie was...       5       True
#
#        prediction
# 34313    0.033970
# 34314    0.025724
# 34315    0.429675
# 34316    0.079010
# 34317    0.046075

# %% [markdown]
# ## Sort the reviews based on the predicted sentiment and explore

# %%
giraffe_reviews = giraffe_reviews.sort_values('prediction')

# %%
giraffe_reviews.head()
# Out:
#                                    name  \
# 34529  Vulli Sophie the Giraffe Teether
# 34760  Vulli Sophie the Giraffe Teether
# 35010  Vulli Sophie the Giraffe Teether
# 35002  Vulli Sophie the Giraffe Teether
# 34561  Vulli Sophie the Giraffe Teether
#
#                                                                                                                                                                                                                                                                                                                                                             review  \
# 34529               I hesitated to buy this because it was such a high price for a simple toy, but after hearing so many great things, I decided to order for my little guy.  He LOVES it!  It is one of his favorite toys, and was worth every penny!  I will definitely keep it in mind for friends family members who have babies.  It would make a great gift.
# 34760                                                                                                                                                                                                              We love Sophie!! Perfect toy/teether for a fussy baby! Our daughter loves holding Sophie, worth every penny!!! Highly recommend for all babies!
# 35010                                                                                                                                      Bought this for my 4 month old nephew who was teething. My grandaughter also has one and loves it. Just the right size and feel. Has quickly become a favorite. I think they would highly recommend Sophie the giraffe!
# 35002                                                                                                                                                    My daughter instantly loved Sophie when I handed it to her.  This is perfect for her gums and her tooth that is coming in.  I highly recommend this to every mom and dad.  My daughter is a lot happier!!
# 34561  This was recommended to me by a friend. I bought it when my daughter was 3 months old and she loves it! she chews on it wherever we go and it is always with us! she smiles when we squeak it and she can manipulate it very well! we are actually buying a 2nd one to have as a backup in case we lose the first. We highly recommend this to all parents.
#
#        rating  sentiment  prediction
# 34529       5       True    0.005882
# 34760       5       True    0.006824
# 35010       5       True    0.008304
# 35002       5       True    0.009808
# 34561       5       True    0.010162

# %%
pd.options.display.max_colwidth = 1000
giraffe_reviews.iloc[0].review
# Out:
# "This children's toy is nostalgic and very cute. However, there is a distinct rubber smell and a very odd taste, yes I tried it, that my baby did not enjoy. Also, if it is soiled it is extremely difficult to clean as the rubber is a kind of porus material and does not clean well. The final thing is the squeaking device inside which stopped working after the first couple of days. I returned this item feeling I had overpaid for a toy that was defective and did not meet my expectations. Please do not be swayed by the cute packaging and hype surounding it as I was. One more thing, I was given a full refund from Amazon without any problem."

# %% [markdown]
# ## Most positive reviews

# %%
pd.options.display.max_colwidth = 1000
giraffe_reviews.iloc[0].review
# Out:
# 'I hesitated to buy this because it was such a high price for a simple toy, but after hearing so many great things, I decided to order for my little guy.  He LOVES it!  It is one of his favorite toys, and was worth every penny!  I will definitely keep it in mind for friends family members who have babies.  It would make a great gift.'

# %%
giraffe_reviews.iloc[1].review
# Out:
# 'We love Sophie!! Perfect toy/teether for a fussy baby! Our daughter loves holding Sophie, worth every penny!!! Highly recommend for all babies!'

# %% [markdown]
# ## Show most negative reviews

# %%
giraffe_reviews.iloc[-1].review
# Out:
# "This children's toy is nostalgic and very cute. However, there is a distinct rubber smell and a very odd taste, yes I tried it, that my baby did not enjoy. Also, if it is soiled it is extremely difficult to clean as the rubber is a kind of porus material and does not clean well. The final thing is the squeaking device inside which stopped working after the first couple of days. I returned this item feeling I had overpaid for a toy that was defective and did not meet my expectations. Please do not be swayed by the cute packaging and hype surounding it as I was. One more thing, I was given a full refund from Amazon without any problem."

# %%
giraffe_reviews.iloc[-2].review
# Out:
# 'I wanted to love this product and was excited to buy it when I became pregnant but am now hesitant to let my baby use it after reading about the recall in Europe. Apparently, as I understand it, their toxin standards of measurement are lower than ours so they have not been recalled here (apparently we are OK with low levels of nitrates in the toys our children put in their mouths, but Europeans are not...hmmm)...Be that as it may, toxins registering even CLOSE to a dangerous level made me nervous about using. After digging around online I did discover that the company claims to have changed the product after a certain date and lists manufacturing codes so you can check yours (those listed were made after a certain date and are said to be safer). Sadly mine was not made after the &#34;improved&#34; date but I could not return it because there was no formal recall in our country. I considered returning it and hunting for one with an approved manufacturing date but man that was just too much work. Bummed but not ready to take a risk with my baby.'
